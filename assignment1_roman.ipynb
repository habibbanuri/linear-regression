# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('uni dataset.csv')
print(data.describe())
X = data['YearsExperience']
Y = data['salary']
mean_x = np.mean(X)
mean_y = np.mean(Y)
size = len(X)

numerator = 0
denominator = 0
for i in range(size):
    numerator += (X[i] - mean_x)*(Y[i] - mean_y)
    denominator += (X[i]-mean_x) ** 2
m = numerator/denominator
c = mean_y - (m * mean_x)
c
# Out:
#        YearsExperience  publication  TeachingEvaluation        salary
# count       137.000000   137.000000          137.000000  1.370000e+02
# mean          3.467153     8.569343            4.644526  2.743182e+05
# std           1.538960     5.335502            0.536179  6.407838e+05
# min           1.000000     1.000000            2.000000  7.600000e+03
# 25%           2.000000     5.000000            4.500000  2.500000e+04
# 50%           3.000000     8.000000            4.700000  5.000000e+04
# 75%           5.000000    12.000000            5.000000  7.800000e+04
# max           6.000000    23.000000            6.400000  2.300000e+06
# 61807.9314720814

# %%
max_x = np.max(X) + 100
min_x = np.min(X) - 100

x = np.linspace(min_x, max_x, 1000)
y =  m*x + c

import matplotlib.pyplot as plt

plt.plot(x, y, color='Blue', label='Regression Line')
plt.scatter(X, Y, c='#ef5423', label='Scatter Plot')

plt.xlabel('YearsExperience')
plt.ylabel('salary')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
n = 0
d = 0
for i in range(size):
    y_pred = m * X[i] + c
    n += (y_pred-mean_y) **2
    d += (Y[i] - mean_y) **2
r_square = n/d
r_square
# Out:
# 0.021669338249351838
